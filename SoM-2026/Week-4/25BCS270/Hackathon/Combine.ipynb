# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('xgb_submission.csv')
df2 = pd.read_csv('submission30.csv')
df3 = pd.read_csv('submission40.csv')
df4 = pd.read_csv('submission50.csv')
df5 = pd.read_csv('submission60.csv')
# df6 = pd.read_csv('submission70.csv')
#df7 = pd.read_csv('submission80.csv')
df8 = pd.read_csv('submission90.csv')
df9 = pd.read_csv('submission100.csv')
df10 = pd.read_csv('submission200.csv')
df11 = pd.read_csv('submission300.csv')
df12 = pd.read_csv('submission400.csv')
df13 = pd.read_csv('submission500.csv')
df14 = pd.read_csv('submission600.csv')
df15 = pd.read_csv('submission700.csv')
df16 = pd.read_csv('submission800.csv')

# %%
df1['Rented_Bike_Count']
# Out:
# 0       6.914442
# 1       6.773854
# 2       6.559676
# 3       6.203844
# 4       5.663420
#           ...
# 2179    6.221458
# 2180    6.128600
# 2181    6.005744
# 2182    5.997662
# 2183    5.691957
# Name: Rented_Bike_Count, Length: 2184, dtype: float64

# %%
data = [df1, df2, df3, df4, df5, df8, df9, df10, df11, df12, df13, df14, df15, df16]
# for i in data:
#     fig , ax = plt.subplots(figsize = (10,8))
#     sns.scatterplot(data = i, x = 'Id', y = 'Rented_Bike_Count', ax = ax)
#     plt.show()
#     plt.close()

ind = pd.read_csv('Index.csv')
def zero(a):
    if a <0:
        return 0
    return a
count = 1
for i in data:
    i.iloc[ind['Index'], 1] = 0
    fig , ax = plt.subplots()
    sns.scatterplot(data = i, x = 'Id', y = 'Rented_Bike_Count', ax = ax)
    plt.show()
    plt.close()
    print(count)
    count += 1
    display(i.describe())



# for i in data:
#     fig , ax = plt.subplots(figsize = (10,8))
#     sns.scatterplot(data = i, x = 'Id', y = 'Rented_Bike_Count', ax = ax)
#     plt.show()
#     plt.close()
# Out:
# 1
#                 Id  Rented_Bike_Count
# count  2184.000000        2184.000000
# mean   7667.500000           5.539346
# std     630.610815           2.163919
# min    6576.000000           0.000000
# 25%    7121.750000           5.183533
# 50%    7667.500000           6.245539
# 75%    8213.250000           6.885819
# max    8759.000000           8.050673
# 2
#                 Id  Rented_Bike_Count
# count  2184.000000        2184.000000
# mean   7667.500000           5.558365
# std     630.610815           2.177142
# min    6576.000000           0.000000
# 25%    7121.750000           5.231437
# 50%    7667.500000           6.295987
# 75%    8213.250000           6.904756
# max    8759.000000           8.161831
# 3
#                 Id  Rented_Bike_Count
# count  2184.000000        2184.000000
# mean   7667.500000           5.543064
# std     630.610815           2.160113
# min    6576.000000           0.000000
# 25%    7121.750000           5.208653
# ...

# %%
combined = df1['Rented_Bike_Count']
display(combined)
for i in data:
    combined = combined + i['Rented_Bike_Count']
    

combined = combined - df1['Rented_Bike_Count'] 
combined = combined + 3*(df1['Rented_Bike_Count']) + 3*(df2['Rented_Bike_Count']) + 3*(df3['Rented_Bike_Count']) + 4*(df16['Rented_Bike_Count']) + 3*(df15['Rented_Bike_Count'])
combined = combined / 30
combined
# Out:
# 0       6.914442
# 1       6.773854
# 2       6.559676
# 3       6.203844
# 4       5.663420
#           ...
# 2179    6.221458
# 2180    6.128600
# 2181    6.005744
# 2182    5.997662
# 2183    5.691957
# Name: Rented_Bike_Count, Length: 2184, dtype: float64
# 0       6.886590
# 1       6.723513
# 2       6.405894
# 3       6.026437
# 4       5.531805
#           ...
# 2179    6.443263
# 2180    6.172509
# 2181    6.123884
# 2182    6.019983
# 2183    5.766764
# Name: Rented_Bike_Count, Length: 2184, dtype: float64

# %%
solution = pd.DataFrame({
    'Id' : df1['Id'],
    'Rented_Bike_Count':combined
    })

# %%
sns.scatterplot(solution, x=solution.index, y="Rented_Bike_Count")
# Out:
# <Axes: xlabel='None', ylabel='Rented_Bike_Count'>

# %%
solution.to_csv('combined.csv', index=False)
solution.describe()
# Out:
#                 Id  Rented_Bike_Count
# count  2184.000000        2184.000000
# mean   7667.500000           5.544613
# std     630.610815           2.163176
# min    6576.000000           0.000000
# 25%    7121.750000           5.193198
# 50%    7667.500000           6.282401
# 75%    8213.250000           6.889964
# max    8759.000000           8.041448
