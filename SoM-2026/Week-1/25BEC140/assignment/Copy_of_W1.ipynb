# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first graded assignment! Hope that you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We have got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
url="https://drive.google.com/uc?export=download&id=1n_WVE7ax4gomqDyLvDFUYh8kTGQG38uz"
data=pd.read_csv(url)

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
data.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
updatedata=data.copy()
updatedata=updatedata.drop("#",axis=1)
updatedata
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
updatedata.rename(columns={
    'Name':"Index"
})
# Out:
#                      Index   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
updatedata["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
updatedata=updatedata.assign(new_column=updatedata["Type 1"]+"+"+updatedata["Type 2"])
updatedata[(updatedata['Type 1']=="Psychic") & (updatedata['Type 2']=='Flying')]
# Out:
#          Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 191      Natu  Psychic  Flying    320   40      50       45       70       45
# 192      Xatu  Psychic  Flying    470   65      75       70       95       70
# 269     Lugia  Psychic  Flying    680  106      90      130       90      154
# 586    Woobat  Psychic  Flying    313   55      45       43       55       43
# 587   Swoobat  Psychic  Flying    425   67      57       55       77       55
# 622  Sigilyph  Psychic  Flying    490   72      58       80      103       80
#
#      Speed  Generation  Legendary      new_column
# 191     70           2      False  Psychic+Flying
# 192     95           2      False  Psychic+Flying
# 269    110           2       True  Psychic+Flying
# 586     72           5      False  Psychic+Flying
# 587    114           5      False  Psychic+Flying
# 622     97           5      False  Psychic+Flying

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
updatedata["Name"].str.contains('Mega').sum()
# Out:
# np.int64(49)

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
updatedata.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
updatedata.max('Defense')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     575         try:
# --> 576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
#
# KeyError: 'Defense'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5481/4083625288.py in <cell line: 0>()
# ----> 1 updatedata.max('Defense')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in max(self, axis, skipna, numeric_only, **kwargs)
#   11654         **kwargs,
#   11655     ):
# > 11656         result = super().max(axis, skipna, numeric_only, **kwargs)
#   11657         if isinstance(result, Series):
#   11658             result = result.__finalize__(self, method="max")
#
# ...

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
updatedata.groupby('Name')["Defense"].max().sort_values(ascending=False)
# Out:
# Name
# SteelixMega Steelix    230
# Shuckle                230
# AggronMega Aggron      230
# Steelix                200
# Regirock               200
#                       ...
# Smoochum                15
# Igglybuff               15
# Blissey                 10
# Chansey                  5
# Happiny                  5
# Name: Defense, Length: 800, dtype: int64

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
poison_pokemon = data[(data['Type 1'] == 'Poison') | (data['Type 2'] == 'Poison')]
poison_pokemon.groupby('Name')["Attack"].max().sort_values(ascending=False)
# Out:
# Name
# BeedrillMega Beedrill    150
# Toxicroak                106
# Victreebel               105
# Muk                      105
# Nidoking                 102
#                         ...
# Tentacool                 40
# Gastly                    35
# Weedle                    35
# Budew                     30
# Kakuna                    25
# Name: Attack, Length: 62, dtype: int64

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
sns.lineplot(x=data['Type 1'],y=data['Speed'])
plt.tight_layout()

# %%
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here

# %% [markdown]
# ## ***Bonus Questions***
# ## Here are some bonus questions that you can try further !
#
# ### These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
updatedata1=updatedata.assign(highest_combined=updatedata['Attack']+updatedata["Sp. Atk"])
updatedata1.groupby("Name")['highest_combined'].max().sort_values(ascending=False)

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
legendary_pokemon=data[data['Legendary']==True]
legendary_pokemon.groupby('Type 1')['Legendary'].count().sort_values(ascending=False)
# Out:
# Type 1
# Psychic     14
# Dragon      12
# Fire         5
# Steel        4
# Rock         4
# Ground       4
# Electric     4
# Water        4
# Grass        3
# Flying       2
# Dark         2
# Normal       2
# Ghost        2
# Ice          2
# Fairy        1
# Name: Legendary, dtype: int64

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
data

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
updatedata.groupby('Name')["HP"].mean().sort_values(ascending=False)
