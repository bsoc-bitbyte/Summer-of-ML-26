# %% [markdown]
# ### 1) Import Pandas and Numpy

# %%
#your code here
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2) Import the dataset and  Assign it to a variable called Chipo
#
# #### Import the dataset from
# https://github.com/justmarkham/pandas-videos/blob/master/data/chipotle.tsv
#
# #### REMEMBER: It is a .tsv file , you will have to do some research on how to read .tsv files first!

# %%
#your code here
#url="https://github.com/justmarkham/pandas-videos/blob/master/data/chipotle.tsv"
df=pd.read_csv(r"C:\Users\Yash Tripathi\Downloads\chipotle.tsv",sep='\t')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### 3) See the first 10 entries

# %%
#your code here
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# ### 4) What is the number of observations in the dataset?

# %%
#your code here
print(df.shape[0])
# Out:
# 4622

# %% [markdown]
# ### 5) What is the number of columns in the dataset?

# %%
#your code here
print(len(df.columns))
# Out:
# 5

# %% [markdown]
# ### 6) Print the name of all the columns.

# %%
#your code here
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### 7) Which was the most-ordered item?

# %%
#your code here
df['quantity'].idxmax()
# Out:
# 3598

# %% [markdown]
# ### 8) For the most-ordered item, how many items were ordered?

# %%
#your code here
df['quantity'].max()
# Out:
# 15

# %% [markdown]
# ### 9) What was the most ordered item in the choice_description column?

# %%
#your code here
df['choice_description'].value_counts().idxmax()
# Out:
# '[Diet Coke]'

# %% [markdown]
# ### 10) How many items were ordered in total?

# %%
#your code here
df['quantity'].sum()
# Out:
# np.int64(4972)

# %% [markdown]
# ### 11) Turn the item price into a float

# %%
#your code here
df['item_price'] = df['item_price'].apply(lambda x: float(x[1:]) if isinstance(x, str) else x)

# Step 2: Ab data type check karein (yeh float64 dikhayega)
print(df['item_price'].dtype)
# Out:
# float64

# %% [markdown]
# ### 12) How much was the revenue for the period in the dataset?
# #### Revenue will be the sum of quantity * item_price!

# %%
#your code 
revenue = (df['quantity'] * df['item_price']).sum()

print(round(revenue, 2))
# Out:
# 39237.02

# %% [markdown]
# ### 13) How many orders were made in the period?

# %%
#your code here
df['quantity'].sum()
# Out:
# np.int64(4972)

# %% [markdown]
# ### 14) What is the average revenue amount per order?

# %%
#your code here
print((df['item_price']/df['quantity']).mean())
# Out:
# 7.084424491562094

# %% [markdown]
# ### 15) How many different items are sold?

# %%
#your code here
df['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# ### 16) Show a histogram with number of orders with bill on the x-axis.
