# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first graded assignment! Hope that you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We have got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
pokemon = pd.read_csv(r'C:\Users\Prashant Prabhakar\Downloads\W1_Pokemon.csv', sep=',')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here 
#shape is a attribute so no () used
pokemon.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#your code here
pokemon_columns=pokemon.columns.tolist()

# %%
print(pokemon_columns)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
#your code here
pokemon=pokemon.drop('#', axis=1)

# %%
pokemon.head(20)
# Out:
#                          Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                   Bulbasaur  Grass  Poison    318  45      49       49
# 1                     Ivysaur  Grass  Poison    405  60      62       63
# 2                    Venusaur  Grass  Poison    525  80      82       83
# 3       VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                  Charmander   Fire     NaN    309  39      52       43
# 5                  Charmeleon   Fire     NaN    405  58      64       58
# 6                   Charizard   Fire  Flying    534  78      84       78
# 7   CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8   CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9                    Squirtle  Water     NaN    314  44      48       65
# 10                  Wartortle  Water     NaN    405  59      63       80
# 11                  Blastoise  Water     NaN    530  79      83      100
# ...

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
#your code here
pokemon = pokemon.set_index('Name')

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
pokemon['Type 1'].unique()
# Out:
# <ArrowStringArray>
# [   'Grass',     'Fire',    'Water',      'Bug',   'Normal',   'Poison',
#  'Electric',   'Ground',    'Fairy', 'Fighting',  'Psychic',     'Rock',
#     'Ghost',      'Ice',   'Dragon',     'Dark',    'Steel',   'Flying']
# Length: 18, dtype: str

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
#your code here
pokemon['Type1+Type2']=pokemon['Type 1'] + ' ' +pokemon['Type 2']
pokemon['Type1+Type2'].value_counts()['Psychic Flying']
# Out:
# np.int64(6)

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here
mega = pokemon.index.str.contains('Mega') #Name has became an index and is not column
megaPokemon = pokemon[mega]

# %%
print(len(megaPokemon))
# Out:
# 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
deviation = pokemon['Sp. Def'].std()
print(deviation)
# Out:
# 27.82891579711746

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
legendary_series = pokemon['Legendary']
print(legendary_series)
# Out:
# Name
# Bulbasaur                False
# Ivysaur                  False
# Venusaur                 False
# VenusaurMega Venusaur    False
# Charmander               False
#                          ...
# Diancie                   True
# DiancieMega Diancie       True
# HoopaHoopa Confined       True
# HoopaHoopa Unbound        True
# Volcanion                 True
# Name: Legendary, Length: 800, dtype: bool

# %%
#your code here
legendary_pokemon = pokemon[legendary_series]

# %%
legendary_pokemon.head(20)
# Out:
#                        Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Articuno                  Ice    Flying    580   90      85      100       95
# Zapdos               Electric    Flying    580   90      90       85      125
# Moltres                  Fire    Flying    580   90     100       90      125
# Mewtwo                Psychic       NaN    680  106     110       90      154
# MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100      154
# MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150       70      194
# Raikou               Electric       NaN    580   90      85       75      115
# Entei                    Fire       NaN    580  115     115       85       90
# Suicune                 Water       NaN    580  100      75      115       90
# Lugia                 Psychic    Flying    680  106      90      130       90
# Ho-oh                    Fire    Flying    680  106     130       90      110
# ...

# %%
percentage = (len(legendary_pokemon)/len(pokemon))*100
print(percentage)
# Out:
# 8.125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
max_defence = pokemon['Defense'].max()

# %%
#your code here
print(max_defence)
# Out:
# 230

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
#your code here
#First we will filter
poison_pokemon = pokemon['Type 1'].str.contains('Poison')

# %%
poison_pokemon_table = pokemon[poison_pokemon]
strongest = poison_pokemon_table.loc[poison_pokemon_table['Attack'].idxmax()]

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
#your code here
sns.countplot(data=pokemon, x='Type 1')
plt.xticks(rotation=90)
plt.show()

# %%
#your code here
sns.histplot(data=pokemon, x='Attack', bins=20)
plt.show()

# %%
#your code here
sns.boxplot(data=pokemon, y='Attack')
plt.show()

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here
fourth_gen_poki = pokemon[(pokemon['Generation']==4) & (pokemon['Legendary']==False) & (pokemon['Type 1']=='Ghost')]
fourth_gen_poki.sort_values('Speed', ascending=False, inplace=True)

# %%
fourth_gen_poki.head(20)
# Out:
#           Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Mismagius  Ghost     NaN    495   60      60       60      105      105
# Drifblim   Ghost  Flying    498  150      80       44       90       54
# Drifloon   Ghost  Flying    348   90      50       34       60       44
# Dusknoir   Ghost     NaN    525   45     100      135       65      135
# Spiritomb  Ghost    Dark    485   50      92      108       92      108
#
#            Speed  Generation  Legendary   Type1+Type2
# Name
# Mismagius    105           4      False           NaN
# Drifblim      80           4      False  Ghost Flying
# Drifloon      70           4      False  Ghost Flying
# Dusknoir      45           4      False           NaN
# Spiritomb     35           4      False    Ghost Dark

# %% [markdown]
# Drifblim is that pokemon

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here
charizard_attack = pokemon.loc['Charizard']

# %%
print(charizard_attack)
# Out:
# Type 1                Fire
# Type 2              Flying
# Total                  534
# HP                      78
# Attack                  84
# Defense                 78
# Sp. Atk                109
# Sp. Def                 85
# Speed                  100
# Generation               1
# Legendary            False
# Type1+Type2    Fire Flying
# Name: Charizard, dtype: object

# %%
not_weak = pokemon[
    (pokemon['Defense']<charizard_attack['Defense']) & (pokemon['Attack']>charizard_attack['Attack'])
]
print(len(not_weak))
# Out:
# 134

# %% [markdown]
# ## ***Bonus Questions***
# ## Here are some bonus questions that you can try further !
#
# ### These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
pokemon['Combine']=pokemon['Attack']+pokemon['Sp. Atk']
maxx = pokemon.loc[pokemon['Combine'].idxmax()]
print(maxx)
# Out:
# Type 1                Dragon
# Type 2                Flying
# Total                    780
# HP                       105
# Attack                   180
# Defense                  100
# Sp. Atk                  180
# Sp. Def                  100
# Speed                    115
# Generation                 3
# Legendary               True
# Type1+Type2    Dragon Flying
# Combine                  360
# Name: RayquazaMega Rayquaza, dtype: object

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here
legendarypoki = pokemon[pokemon['Legendary']==True]
print(legendarypoki)
# Out:
#                        Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Articuno                  Ice    Flying    580   90      85      100       95
# Zapdos               Electric    Flying    580   90      90       85      125
# Moltres                  Fire    Flying    580   90     100       90      125
# Mewtwo                Psychic       NaN    680  106     110       90      154
# MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100      154
# ...                       ...       ...    ...  ...     ...      ...      ...
# Diancie                  Rock     Fairy    600   50     100      150      100
# DiancieMega Diancie      Rock     Fairy    700   50     160      110      160
# HoopaHoopa Confined   Psychic     Ghost    600   80     110       60      150
# HoopaHoopa Unbound    Psychic      Dark    680   80     160       60      170
# Volcanion                Fire     Water    600   80     110      120      130
#
# ...

# %%
legendarypoki['Type 1'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type 1'>

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here
weakgen6=pokemon[pokemon['Generation']==6]

# %%
print(weakgen6)
# Out:
#                       Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Chespin                Grass       NaN    313  56      61       65       48
# Quilladin              Grass       NaN    405  61      78       95       56
# Chesnaught             Grass  Fighting    530  88     107      122       74
# Fennekin                Fire       NaN    307  40      45       40       62
# Braixen                 Fire       NaN    409  59      59       58       90
# ...                      ...       ...    ...  ..     ...      ...      ...
# Diancie                 Rock     Fairy    600  50     100      150      100
# DiancieMega Diancie     Rock     Fairy    700  50     160      110      160
# HoopaHoopa Confined  Psychic     Ghost    600  80     110       60      150
# HoopaHoopa Unbound   Psychic      Dark    680  80     160       60      170
# Volcanion               Fire     Water    600  80     110      120      130
#
# ...

# %%
weakgen6legendary = weakgen6[weakgen6['Legendary']==True]
print(weakgen6legendary)
# Out:
#                       Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Xerneas                Fairy     NaN    680  126     131       95      131
# Yveltal                 Dark  Flying    680  126     131       95      131
# Zygarde50% Forme      Dragon  Ground    600  108     100      121       81
# Diancie                 Rock   Fairy    600   50     100      150      100
# DiancieMega Diancie     Rock   Fairy    700   50     160      110      160
# HoopaHoopa Confined  Psychic   Ghost    600   80     110       60      150
# HoopaHoopa Unbound   Psychic    Dark    680   80     160       60      170
# Volcanion               Fire   Water    600   80     110      120      130
#
#                      Sp. Def  Speed  Generation  Legendary    Type1+Type2  \
# Name
# Xerneas                   98     99           6       True            NaN
# Yveltal                   98     99           6       True    Dark Flying
# ...

# %%
weakgen6legendaryhp = weakgen6legendary['HP'].min()

# %%
stronggen3 = pokemon[(pokemon['Legendary']==False) & (pokemon['Generation']==3) & (pokemon['HP']>weakgen6legendaryhp) ]
print(len(stronggen3))
# Out:
# 95

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here
pokemonspeed = pokemon['Speed']
pokemonspeed.sort_values(inplace=True)
pokemonspeed.drop_duplicates(inplace=True)
print(pokemonspeed.iloc[3])
# Out:
# 20

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
print(pokemon.loc[pokemon['HP'].idxmax()])
# Out:
# Type 1         Normal
# Type 2            NaN
# Total             540
# HP                255
# Attack             10
# Defense            10
# Sp. Atk            75
# Sp. Def           135
# Speed              55
# Generation          2
# Legendary       False
# Type1+Type2       NaN
# Combine            85
# Name: Blissey, dtype: object
